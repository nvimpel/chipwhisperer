# %% [markdown]
# ## Nastavnie Jupyter Notebooku
# Ak toto čítaš tak sa ti podarilo spustiť Jupyter. Vyskúšaj si spustiť pár importov. Ak všetko pôjde správne tak by si to nemalo vypísať žiadne výnimky. (Blok s kódom spustíš pomocou SHIFT+ENTER)

# %%
import chipwhisperer
help(chipwhisperer)

# %% [markdown]
# Následujúci kód by mal vygenerovať graf.

# %%
import matplotlib.pylab as plt
plt.plot(range(0, 10))

# %% [markdown]
# ## Test hardvéru chipwhisperera
# Pomocou následujúceho kódu sa pokúsime o kumunikáciu s chipwhispererom
# Ak sa všetko podarí správne malo by sa zobraziť
# *INFO: ChipWhisperer nájdený😍*

# %%
PLATFORM="NOTHING"
# %run Setup_Scripts/Setup_Generic.ipynb

# %% [markdown]
# Keď sa chceme odpojiť od chipwhisperera použijeme

# %%
scope.dis()
target.dis()

# %% [markdown]
# Ak budeš vytvárať zdrojový kód, potrebuješ funkčný systém Make. Najprv skontroluj, či vieš spustiť príkaz make – ten by mal vypísať štandardný výstup.

# %%
# !make --version

# %% [markdown]
# Ak budeš používať niektorý z následovných, budeš potrebovať `arm-none-eabi-gcc` compiler
# - ChipWhisperer-Lite 32-bit (with Arm Target).
# - ChipWhisperer UFO Board with any Arm target (such as STM32F3, STM32F0, etc).
# - ChipWhisperer-Nano
# Skontroluj spustením následovného príkazu

# %%
# !arm-none-eabi-gcc -v

# %% [markdown]
# Ak budeš používať niektorý z následovných, budeš potrebovať `avr-gcc` compiler
# - ChipWhisperer-Lite Classic (with XMEGA Target).
# - ChipWhisperer UFO Board with XMEGA or AVR Target.
# - ChipWhisperer-Lite 2-Part Version.
# Skontroluj spustením následovného príkazu

# %%
# !avr-gcc -v

# %% [markdown]
# ## Záver
# Tak to by sme mali. Ak všetko fungovalo bez problémov tak by sme mali vedieť pracovať s chipwhispererom bez problémov.
